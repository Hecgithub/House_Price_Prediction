# %% [markdown]
# # Final Project: House Price Prediction
# ## Corpus Christi Team
# ### Step 5 (Machine Learning Model for House Prediction)

# %%
# Import general use libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import os
import glob
import math
import csv
import warnings
from time import sleep
from tqdm import tqdm
from datetime import datetime as dt

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# Import ML related libraries
import seaborn as sns
import sklearn.datasets
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression
from xgboost import plot_importance
from shapash.explainer.smart_explainer import SmartExplainer

# Import database related libraries
import psycopg2
import psycopg2.extras
from config import db as dbpwd

# %% [markdown]
# #### Read the input data for ML (Can be read from a folder or from a PostGreSQL DB)

# %%
# Define the input data path and input file name
data_path = "../03_Data_Cleaning/data/*.csv"
listing = glob.glob(data_path)

for file in listing:
    if '03b_preprocessed_data' in file:
        input_file = file
        print(f'The input file is {file}')

regex = "(data_.+).csv"
match = re.findall(rf"{regex}", input_file)
name = ''.join(match)
db_table_name = name.lower()
print(f'The input file will be saved to the db as a table named: {db_table_name}')
# Out:
# The input file is ../03_Data_Cleaning/data\03b_preprocessed_data_Houston_TX_Houses_merged_2023_1_8_12_2.csv
# The input file will be saved to the db as a table named: data_houston_tx_houses_merged_2023_1_8_12_2

# %%
# Read from DB
hostname = 'localhost'
database = 'real_estate_data_test'
username = 'postgres'
pwd = dbpwd
port_id = 5432
conn = None
cur = None

with psycopg2.connect("host='{}' port={} dbname='{}' user={} password={}".format(hostname, port_id, database, username, pwd)) as conn:
    sql = "select * from {};".format(db_table_name)
    df = pd.read_sql_query(sql, conn)

df
# Out:
#              zid state     city                                       address  \
# 0       27541924    TX  Houston  6602 Indian Lake Dr, Missouri City, TX 77489
# 1       27542111    TX  Houston   6727 Castleview Ln, Missouri City, TX 77489
# 2       27542455    TX  Houston   15902 Ridgerock Rd, Missouri City, TX 77489
# 3       27542890    TX  Houston   15806 Blueridge Rd, Missouri City, TX 77489
# 4       27543383    TX  Houston   6919 Rockergate Dr, Missouri City, TX 77489
# ...          ...   ...      ...                                           ...
# 4495  2125126583    TX  Houston              627 W 25th St, Houston, TX 77008
# 4496  2125214802    TX  Houston              4608 Inker St, Houston, TX 77007
# 4497  2127408520    TX  Houston               3570 Noah St, Houston, TX 77021
# 4498  2134060336    TX  Houston      5234 Cornish St STE A, Houston, TX 77007
# 4499  2146923223    TX  Houston       11211 Switchgrass Ln, Houston, TX 77095
#
#             lat        lng   price  \
# 0     29.603600 -95.485405  276000
# 1     29.600388 -95.488210  220000
# 2     29.595436 -95.485880  230000
# 3     29.597320 -95.492690  225000
# 4     29.592060 -95.489050  246500
# ...         ...        ...     ...
# 4495  29.808900 -95.408710  669900
# 4496  29.775753 -95.407600  519000
# 4497  29.685492 -95.371700  550000
# 4498  29.778660 -95.415340  450000
# 4499  29.936180 -95.678500  499000
#
#                                                   image  bedrooms  bathrooms  \
# 0     https://photos.zillowstatic.com/fp/bc5a7196226...         3          2
# 1     https://photos.zillowstatic.com/fp/1336380a837...         3          2
# 2     https://photos.zillowstatic.com/fp/5603ce32232...         4          2
# 3     https://photos.zillowstatic.com/fp/4d5e3792d33...         3          2
# 4     https://maps.googleapis.com/maps/api/staticmap...         3          2
# ...                                                 ...       ...        ...
# 4495  https://photos.zillowstatic.com/fp/0e126fa6bb3...         3          3
# 4496  https://photos.zillowstatic.com/fp/7d8db8b600e...         3          4
# 4497  https://photos.zillowstatic.com/fp/17b624955d6...         1          2
# 4498  https://photos.zillowstatic.com/fp/06157f370ad...         3          4
# 4499  https://photos.zillowstatic.com/fp/60ab4fb8798...         6          4
#
#           lotarea  constructedarea  zipcode  countyid  taxrate  hasgarage  \
# 0     8764.272000           3612.0    77489      2698     2.41          1
# 1     7884.360000           1270.0    77489      2698     2.41          1
# 2     7148.196000           1765.0    77489      2698     2.41          1
# 3     7731.900000           1444.0    77489      2698     2.41          1
# 4     8062.956000           1738.0    77489      2698     2.41          1
# ...           ...              ...      ...       ...      ...        ...
# 4495  3275.000000           2576.0    77008      1090     2.29          1
# 4496  2330.460000           2513.0    77007      1090     2.29          1
# 4497     0.344353           5160.0    77021      1090     2.29          1
# 4498  2051.676000           2148.0    77007      1090     2.29          1
# 4499  5136.566847           3857.0    77095      1090     2.29          1
#
#       haspool  hascooling  hasview  yearbuilt  stories  parkingspaces  \
# 0           0           1        0       1971        2              2
# 1           0           1        0       1972        1              1
# 2           0           1        0       1974        1              2
# 3           0           1        0       1978        1              2
# 4           0           1        0       1978        1              2
# ...       ...         ...      ...        ...      ...            ...
# 4495        0           1        0       2022        2              2
# 4496        0           1        0       2006        3              2
# 4497        0           1        0       1952        1              2
# 4498        0           1        0       2007        3              2
# 4499        0           1        0       2005        2              2
#
#       annualhoi      annualhoa  schoolelemrating  schoolelemdist  \
# 0          1159  $400 annually                 6             0.5
# 1           924  $144 annually                 6             0.3
# 2           966  $250 annually                 6             0.3
# 3           945                                6             0.1
# 4          1035  $144 annually                 6             0.3
# ...         ...            ...               ...             ...
# 4495       2814                                5             0.3
# 4496       2180                                8             1.2
# 4497       2310                                2             0.3
# 4498       1890                                4             1.0
# 4499       2096  $900 annually                 7             0.5
#
#       schoolmidrating  schoolmiddist  schoolhighrating  schoolhighdist  \
# 0                   3            1.3                 2             1.1
# 1                   3            1.3                 2             1.0
# 2                   3            1.0                 2             0.6
# 3                   3            1.4                 2             1.0
# 4                   3            1.0                 2             0.6
# ...               ...            ...               ...             ...
# 4495                5            0.7                 5             1.3
# 4496                6            1.6                 5             1.5
# 4497                3            0.6                 2             2.5
# 4498                6            2.0                 3             2.7
# 4499                9            2.0                 8             2.2
#
#       priceincreased  pricediff  days   lotareasqft  avgschoolrating  \
# 0                  1    31000.0  1213   8764.272000         3.666667
# 1                  1    65100.0   503   7884.360000         3.666667
# 2                  1   115275.0  5140   7148.196000         3.666667
# 3                  1    56000.0   824   7731.900000         3.666667
# 4                  1    41500.0  6810   8062.956000         3.666667
# ...              ...        ...   ...           ...              ...
# 4495               1   404900.0  3993   3275.000000         5.000000
# 4496               1   522400.0  4145   2330.460000         6.333333
# 4497               1   375000.0  4219  14999.999997         2.333333
# 4498               0        0.0     0   2051.676000         4.333333
# 4499               0        0.0     0   7775.701340         8.000000
#
#       avgschooldist
# 0          0.966667
# 1          0.866667
# 2          0.633333
# 3          0.833333
# 4          0.633333
# ...             ...
# 4495       0.766667
# 4496       1.433333
# 4497       1.133333
# 4498       1.900000
# 4499       1.566667
#
# [4500 rows x 36 columns]

# %%
# Read from folder

# Create the input DF
#df = pd.read_csv(input_file)
#df.head(3)

# %% [markdown]
# #### Do some additional ML conditioning based on previous testing

# %%
# Based on previous testing, remove low-weight and unnecessary features
df = df.drop(['zid', 'address', 'lotarea', 'image', 'countyid', 'taxrate', 'annualhoa', 'annualhoi', 'state', 'city', 'days', 'pricediff', 'priceincreased', 'lat', 'lng', 'schoolelemrating', 'schoolmidrating', 'schoolhighrating', 'schoolelemdist', 'schoolmiddist', 'schoolhighdist', 'hasview', 'hascooling', 'haspool', 'hasgarage', 'stories', 'parkingspaces'], axis=1)

# %% [markdown]
# #### Save the DF conditioned for ML

# %%
ou_name = '05_ML_from_DB_data'+ db_table_name + 'csv'

# Create output directory if it does not exist
ou_path = './data/'
os.makedirs(ou_path, exist_ok=True)

# Save to a csv file
df.to_csv(f'{ou_path}{ou_name}', index=False)

# %% [markdown]
# #### Perform basic QC on the input DF

# %%
# Drop unnecessary columns for ML
df = df.drop([], axis=1)

# %%
# Check if there are any null values
df.isnull().sum()
# Out:
# price              0
# bedrooms           0
# bathrooms          0
# constructedarea    0
# zipcode            0
# yearbuilt          0
# lotareasqft        0
# avgschoolrating    0
# avgschooldist      0
# dtype: int64

# %%
# Get statistics
df.describe()
# Out:
#                price     bedrooms    bathrooms  constructedarea       zipcode  \
# count    4500.000000  4500.000000  4500.000000      4500.000000   4500.000000
# mean   401480.002667     3.393556     2.830667      2158.662015  77070.912667
# std    157007.688575     0.724881     0.887162       711.170309     81.504576
# min    200000.000000     0.000000     0.000000         0.000000  77003.000000
# 25%    280000.000000     3.000000     2.000000      1680.750000  77022.000000
# 50%    364000.000000     3.000000     3.000000      2020.000000  77057.000000
# 75%    469990.000000     4.000000     3.000000      2528.250000  77084.000000
# max    900000.000000    10.000000     7.000000      6793.000000  77598.000000
#
#          yearbuilt    lotareasqft  avgschoolrating  avgschooldist
# count  4500.000000    4500.000000      4500.000000    4500.000000
# mean   1993.300222    7776.873718       108.415534     105.570933
# std      28.878517   22153.124331       304.181863     305.144595
# min    1888.000000       0.000000         2.000000       0.166667
# 25%    1970.000000    4225.757000         3.333333       0.933333
# 50%    2003.000000    6993.558000         4.333333       1.333333
# 75%    2022.000000    8160.000000         6.000000       1.966667
# max    2023.000000  980100.000000       999.000000     999.000000

# %%
# Print the DF that is input to the ML algorithm
df
# Out:
#        price  bedrooms  bathrooms  constructedarea  zipcode  yearbuilt  \
# 0     276000         3          2           3612.0    77489       1971
# 1     220000         3          2           1270.0    77489       1972
# 2     230000         4          2           1765.0    77489       1974
# 3     225000         3          2           1444.0    77489       1978
# 4     246500         3          2           1738.0    77489       1978
# ...      ...       ...        ...              ...      ...        ...
# 4495  669900         3          3           2576.0    77008       2022
# 4496  519000         3          4           2513.0    77007       2006
# 4497  550000         1          2           5160.0    77021       1952
# 4498  450000         3          4           2148.0    77007       2007
# 4499  499000         6          4           3857.0    77095       2005
#
#        lotareasqft  avgschoolrating  avgschooldist
# 0      8764.272000         3.666667       0.966667
# 1      7884.360000         3.666667       0.866667
# 2      7148.196000         3.666667       0.633333
# 3      7731.900000         3.666667       0.833333
# 4      8062.956000         3.666667       0.633333
# ...            ...              ...            ...
# 4495   3275.000000         5.000000       0.766667
# 4496   2330.460000         6.333333       1.433333
# 4497  14999.999997         2.333333       1.133333
# 4498   2051.676000         4.333333       1.900000
# 4499   7775.701340         8.000000       1.566667
#
# [4500 rows x 9 columns]

# %%
# Heat map
# A heat map shows the correlation between the input data columns
# There are 2 types of correlation:
# Positive: As the magnitude of a feature increases, the magnitude of a correlated feature increases
# Negative: As the magnitude of a feature increases, the magnitude of a correlated feature decreases
correlation = df.corr()
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':8}, cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Get the features and the target column

# %%
# Create a new DataFrame that holds only the cryptocurrencies names.
# X = Features, y = target
X = df.drop('price', axis=1)
y = df[["price"]]

# %% [markdown]
# #### Split the data for training and testing

# %%
# Use 20% of data for testing. Use a random_state = 2 to be able to reproduce the splitting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (4500, 8) (3600, 8) (900, 8)

# %% [markdown]
# #### Model Training

# %%
# Load the model (XGBoost Regressor)
model = XGBRegressor()

# Train the model with the training data
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %% [markdown]
# #### Make predictions using the test data

# %%
y_pred = model.predict(X_test)

# Calculate the R squared error
error_r2 = metrics.r2_score(y_test, y_pred)

# Calculate the mean absolute error
error_ma = metrics.mean_absolute_error(y_test, y_pred)

print(f'R squared error: {error_r2} (should be close to 1)')
# Out:
# R squared error: 0.7629628825325383 (should be close to 1)

# %%
# Plot the features importance
plt.rcParams.update({'font.size': 12})
fig, ax = plt.subplots(figsize=(12,6))
plot_importance(model, ax=ax)
plt.show();

# %%
# Display the actual price vs the predicted price
y_test_df = y_test.reset_index(drop=True)
y_test_df = y_test_df.rename(columns = {'Price':'Actual_Price'})

y_pred_df = pd.DataFrame(y_pred, columns = ['Predicted_Price'])
y_pred_df = y_pred_df['Predicted_Price'].apply(np.ceil).astype('int')

# Display the actual and the predicted prices side by side
df_prices = pd.concat([y_test_df, y_pred_df], axis=1)
df_prices
# Out:
#       price  Predicted_Price
# 0    280000           325345
# 1    260000           282755
# 2    409990           433496
# 3    825000           719726
# 4    599900           604939
# ..      ...              ...
# 895  474500           343268
# 896  249500           239515
# 897  399900           359075
# 898  599000           560041
# 899  219000           249513
#
# [900 rows x 2 columns]

# %%
# Scatter Plot using test data
plt.scatter(y_test_df, y_pred_df)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('HPP Scatter Plot: Test Data')
plt.show()

# %% [markdown]
# ### Understanding the model with Shapash
# #### If not installed, run the following command in your conda environment
# !pip install shapash

# %%
# Initialize shapash with the ML model
xpl = SmartExplainer(model)

# %%
# Condition X_test and y_pred for Shapash
# Display the actual price vs the predicted price
temp = X_test.reset_index(drop=True)
sp_X_test = temp.rename(columns = {'Price':'Price'})
del(temp)

temp = pd.DataFrame(y_pred, columns = ['Price'])
sp_y_pred = temp['Price'].apply(np.ceil).astype('int')
del(temp)

temp = y_test.reset_index(drop=True)
sp_y_target = temp.rename(columns = {'Price':'Price'})
del(temp)

# %%
# Compile shapash
xpl.compile(x=sp_X_test, y_pred=sp_y_pred, y_target=sp_y_target)

# %%
app = xpl.run_app(title_story='House_Price_Prediction')
# Out:
# Dash is running on http://0.0.0.0:8050/
# INFO:root:Your Shapash application run on http://Oscar:8050/
# INFO:shapash.webapp.smart_app:Dash is running on http://0.0.0.0:8050/
#
# INFO:root:Use the method .kill() to down your app.
#  * Serving Flask app 'shapash.webapp.smart_app' (lazy loading)

# %%
# Plot a summary with the contribution of the features
summary_df = xpl.to_pandas(max_contrib=14) #Number of max features to show in summary
summary_df.head()
# Out:
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#     Price        feature_1  value_1 contribution_1        feature_2   value_2  \
# 0  325345          zipcode  77489.0   -68947.46875  constructedarea    2836.0
# 1  282755  constructedarea   1500.0  -71090.078125  avgschoolrating  3.666667
# 2  433496        yearbuilt   2022.0   31037.611328  constructedarea    1926.0
# 3  719726  constructedarea   3530.0    171693.8125          zipcode   77079.0
# 4  604939          zipcode  77004.0   98031.101562  constructedarea    2610.0
#
#   contribution_2  feature_3  value_3 contribution_3        feature_4  \
# 0   58311.566406  yearbuilt   1978.0       -37705.5        bathrooms
# 1  -24489.416016  yearbuilt   1946.0   15926.702148         bedrooms
# 2  -24085.978516    zipcode  77011.0   22148.392578  avgschoolrating
# 3   91830.554688  bathrooms      4.0   43384.679688  avgschoolrating
# 4   91656.859375  yearbuilt   2023.0   31602.257812  avgschoolrating
#
#     value_4 contribution_4        feature_5   value_5 contribution_5  \
# 0       3.0   -7475.969727  avgschoolrating       4.0   -6201.688965
# 1       4.0  -11800.207031          zipcode   77021.0   -9495.790039
# 2  3.666667  -19384.351562    avgschooldist  0.666667   13929.183594
# 3  5.333333   36161.550781        yearbuilt    1978.0  -32909.804688
# 4       4.0  -26006.029297         bedrooms       3.0   15359.724609
#
#        feature_6    value_6 contribution_6      feature_7   value_7  \
# 0       bedrooms        4.0   -5722.767578    lotareasqft  7200.468
# 1  avgschooldist   1.166667   -8434.964844      bathrooms       2.0
# 2    lotareasqft  10001.376   11566.679688      bathrooms       3.0
# 3    lotareasqft   8637.948   12320.919922  avgschooldist       0.6
# 4  avgschooldist        2.0   -9493.727539      bathrooms       4.0
#
#   contribution_7      feature_8     value_8 contribution_8
# 0   -4644.782715  avgschooldist    1.766667   -2389.024658
# 1   -7916.427246    lotareasqft  7775.70134     -65.609329
# 2   -6289.938965       bedrooms         3.0    4453.683594
# 3   -9131.894531       bedrooms         3.0    6254.856445
# 4    3747.159668    lotareasqft    3249.576      -78.87175
# WARNING:werkzeug: * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
# INFO:werkzeug: * Running on http://192.168.1.228:8050/ (Press CTRL+C to quit)

# %%
# Kill the dashboard (Run when done)
#app.kill
