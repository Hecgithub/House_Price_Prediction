# %% [markdown]
# # Final Project: House Price Prediction
# ## Corpus Christi Team
# ### Step 3c (Prepare the data for ML)

# %% [markdown]
# Remove unnecessary columns for ML, replace empty or invalid cells,
# assign data types, encode, etc.

# %% [markdown]
# #### Import requested libraries

# %%
import pandas as pd
import requests
import json
import re
import os
import glob
from datetime import datetime as dt
import warnings
from time import sleep
from tqdm import tqdm

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# Import your RapidAPI key
from config import krapid as key

# %% [markdown]
# #### Read the input data

# %%
# Load the input data (only the most recent file)
data_path = "data/*.csv"
listing = glob.glob(data_path)
latest_file = max(listing, key=os.path.getctime)
print(f'The file selected is: {latest_file}')
# Out:
# The file selected is: data\fix_cleaned_data_Houston_TX_Houses_merged_2023_1_1_12_5.csv

# %%
# Create the input DF
df_raw = pd.read_csv(latest_file)

# %% [markdown]
# #### Retreive the missing coordinates cells

# %%
# Get the list of zid's where lat and lng are invalid
missing_coordinates_list = df[df['Lat'].isnull()].zid.tolist()
length = len(missing_coordinates_list)

# Create an empty DF, only declare colun names
cnames = ['zid', 'LatOK', "LngOK"]
df_coord = pd.DataFrame(columns=cnames)

i = 1

for zid in missing_coordinates_list:
    # API specific (do not modify)
    host = "zillow-com1.p.rapidapi.com"
    url = "https://" + host + "/property" # Query of single property details

    # API specific (do not modify)
    querystring = {"zpid": zid}

    headers = {
        "X-RapidAPI-Key": key,
        "X-RapidAPI-Host": host
    }

    response = requests.request("GET", url, headers=headers, params=querystring)
    json_response = response.json()
    
    # Max 2 calls per second are allowed
    sleep(0.6)

    # If the response is successful (i.e., 200), then get the property details
    if response.status_code == 200:
        
        latOK = json_response['latitude']
        lngOK = json_response['longitude']
        
        print(f'working in item {i} of {length}, zid: {zid}, lat: {latOK}, lng: {lngOK}')
        
        i = i + 1

        # Append to output DF
        df_row = {'zid': zid, 'LatOK': latOK, 'LngOK': lngOK}
        df_coord = df_coord.append(df_row, ignore_index=True)
# Out:
# working in item 1 of 339, zid: 2061573385, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2061963213, lat: 29.86276, lng: -95.298004
# working in item 1 of 339, zid: 2060675685, lat: 29.898052, lng: -95.179955
# working in item 1 of 339, zid: 2060310473, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062368294, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2063405724, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2061600037, lat: 30.008938, lng: -95.443504
# working in item 1 of 339, zid: 2063176996, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2063178253, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2063178036, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2066644430, lat: 29.602442, lng: -95.44372
# working in item 1 of 339, zid: 2060302552, lat: 29.855608, lng: -95.446785
# working in item 1 of 339, zid: 2061866165, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2061694964, lat: 29.815, lng: -95.348274
# working in item 1 of 339, zid: 2062182219, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062182220, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2061782642, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061782752, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061783173, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061783219, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061783346, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061783462, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061783625, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061783793, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061783846, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061784471, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063003499, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063003530, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063003576, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063003654, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063003743, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063003799, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063003828, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063003887, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063004037, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063004220, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2069113320, lat: 29.832806, lng: -95.41583
# working in item 1 of 339, zid: 2069113321, lat: 29.832806, lng: -95.41583
# working in item 1 of 339, zid: 2069113382, lat: 29.832806, lng: -95.41583
# working in item 1 of 339, zid: 2069113550, lat: 29.832806, lng: -95.41583
# working in item 1 of 339, zid: 2064210993, lat: 29.797062, lng: -95.48026
# working in item 1 of 339, zid: 2061001353, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2061001419, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2061088894, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2062970459, lat: 29.807629, lng: -95.356255
# working in item 1 of 339, zid: 2060752318, lat: 29.588713, lng: -95.22669
# working in item 1 of 339, zid: 2067963862, lat: 29.808102, lng: -95.521935
# working in item 1 of 339, zid: 2067720066, lat: 29.810862, lng: -95.39137
# working in item 1 of 339, zid: 2060897885, lat: 29.79914, lng: -95.48306
# working in item 1 of 339, zid: 2067591835, lat: 29.765203, lng: -95.404144
# working in item 1 of 339, zid: 2061712231, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2060357156, lat: 29.858435, lng: -95.285545
# working in item 1 of 339, zid: 2063177765, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2063178442, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2063219188, lat: 29.834496, lng: -95.14872
# working in item 1 of 339, zid: 2060311195, lat: 29.898052, lng: -95.179955
# working in item 1 of 339, zid: 2062670155, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2063425219, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2062669943, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2060436632, lat: 29.871946, lng: -95.44791
# working in item 1 of 339, zid: 2062669918, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2062670051, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2061017829, lat: 29.608494, lng: -95.38633
# working in item 1 of 339, zid: 2060311190, lat: 29.699856, lng: -95.355316
# working in item 1 of 339, zid: 2060805671, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2078683375, lat: 29.785557, lng: -95.36287
# working in item 1 of 339, zid: 2062547089, lat: 29.957811, lng: -95.50152
# working in item 1 of 339, zid: 2066640500, lat: 29.796974, lng: -95.57524
# working in item 1 of 339, zid: 2062710553, lat: 29.817896, lng: -95.50921
# working in item 1 of 339, zid: 2063179893, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2067027707, lat: 29.822844, lng: -95.42297
# working in item 1 of 339, zid: 2075357297, lat: 29.78938, lng: -95.57772
# working in item 1 of 339, zid: 2071984351, lat: 29.822906, lng: -95.4152
# working in item 1 of 339, zid: 2070417110, lat: 29.79951, lng: -95.419975
# working in item 1 of 339, zid: 2070417394, lat: 29.79966, lng: -95.418945
# working in item 1 of 339, zid: 2065763387, lat: 29.822906, lng: -95.4152
# working in item 1 of 339, zid: 2062948566, lat: 29.767784, lng: -95.41228
# working in item 1 of 339, zid: 2061145283, lat: 29.999355, lng: -95.397705
# working in item 1 of 339, zid: 2064350350, lat: 29.84439, lng: -95.31617
# working in item 1 of 339, zid: 2066461903, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2062669806, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2065546096, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2060296458, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2061186301, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062369095, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2060592915, lat: 29.608494, lng: -95.38633
# working in item 1 of 339, zid: 2060320169, lat: 29.859743, lng: -95.192345
# working in item 1 of 339, zid: 2061575653, lat: 29.778824, lng: -95.35539
# working in item 1 of 339, zid: 2063072596, lat: 29.791746, lng: -95.352135
# working in item 1 of 339, zid: 2064175202, lat: 29.84423, lng: -95.403435
# working in item 1 of 339, zid: 2065712152, lat: 29.831608, lng: -95.40235
# working in item 1 of 339, zid: 2062920826, lat: 29.768906, lng: -95.32409
# working in item 1 of 339, zid: 2062964502, lat: 29.768822, lng: -95.32409
# working in item 1 of 339, zid: 2063244406, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2061776652, lat: 29.797194, lng: -95.49083
# working in item 1 of 339, zid: 2061001578, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2061010705, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2067464113, lat: 29.796646, lng: -95.480125
# working in item 1 of 339, zid: 2065882671, lat: 29.799652, lng: -95.42012
# working in item 1 of 339, zid: 2061809896, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2070488219, lat: 29.7999, lng: -95.41457
# working in item 1 of 339, zid: 2067661341, lat: 29.730276, lng: -95.379684
# working in item 1 of 339, zid: 2061985357, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2062413224, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2066471581, lat: 29.898052, lng: -95.179955
# working in item 1 of 339, zid: 2066462074, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2060744964, lat: 29.619877, lng: -95.266655
# working in item 1 of 339, zid: 2062413125, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2065546275, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2061518722, lat: 29.86092, lng: -95.193054
# working in item 1 of 339, zid: 2061695150, lat: 29.814095, lng: -95.349174
# working in item 1 of 339, zid: 2061186467, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2063388122, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2060999643, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2060343153, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2086424388, lat: 30.016987, lng: -95.112785
# working in item 1 of 339, zid: 2060362270, lat: 29.73581, lng: -95.52097
# working in item 1 of 339, zid: 2069113251, lat: 29.832806, lng: -95.41583
# working in item 1 of 339, zid: 2085542934, lat: 29.844372, lng: -95.40341
# working in item 1 of 339, zid: 2060940629, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2060940686, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2060905909, lat: 29.836266, lng: -95.41629
# working in item 1 of 339, zid: 2060914198, lat: 29.836042, lng: -95.41629
# working in item 1 of 339, zid: 2061455608, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2060952897, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2063177989, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2065776819, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2062413178, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2062669739, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2062669864, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2064114125, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2061189604, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2071020399, lat: 30.029667, lng: -95.10906
# working in item 1 of 339, zid: 2061226814, lat: 29.834496, lng: -95.14872
# working in item 1 of 339, zid: 2082727878, lat: 29.682808, lng: -95.62578
# working in item 1 of 339, zid: 2065712188, lat: 29.831411, lng: -95.40238
# working in item 1 of 339, zid: 2061129764, lat: 29.815758, lng: -95.52348
# working in item 1 of 339, zid: 2061618926, lat: 29.957811, lng: -95.50152
# working in item 1 of 339, zid: 2060362182, lat: 29.73581, lng: -95.52097
# working in item 1 of 339, zid: 2069612240, lat: 29.806538, lng: -95.52782
# working in item 1 of 339, zid: 2062141157, lat: 29.831038, lng: -95.47438
# working in item 1 of 339, zid: 2065147883, lat: 29.699831, lng: -95.35532
# working in item 1 of 339, zid: 2061010437, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2061010621, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2060407532, lat: 29.66843, lng: -95.42536
# working in item 1 of 339, zid: 2067741385, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2062153569, lat: 29.82139, lng: -95.38859
# working in item 1 of 339, zid: 2062254396, lat: 29.569632, lng: -95.24355
# working in item 1 of 339, zid: 2062412951, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2061765361, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2066597183, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2061866597, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062635438, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2063212622, lat: 29.602442, lng: -95.44372
# working in item 1 of 339, zid: 2063345346, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2061207722, lat: 29.898052, lng: -95.179955
# working in item 1 of 339, zid: 2067363025, lat: 29.827637, lng: -95.541275
# working in item 1 of 339, zid: 2061130894, lat: 29.815758, lng: -95.52348
# working in item 1 of 339, zid: 2060496045, lat: 29.73581, lng: -95.52097
# working in item 1 of 339, zid: 2069113700, lat: 29.832806, lng: -95.41583
# working in item 1 of 339, zid: 2064250023, lat: 29.957811, lng: -95.50152
# working in item 1 of 339, zid: 2060805712, lat: 29.822195, lng: -95.39541
# working in item 1 of 339, zid: 2060387702, lat: 29.73581, lng: -95.52097
# working in item 1 of 339, zid: 2067027703, lat: 29.822844, lng: -95.42297
# working in item 1 of 339, zid: 2067027712, lat: 29.82322, lng: -95.423325
# working in item 1 of 339, zid: 2061782568, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061782824, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061784168, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063001127, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063001142, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063001280, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063001661, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063001822, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063001865, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063001880, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063001901, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063001925, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2063001971, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2060363448, lat: 29.73581, lng: -95.52097
# working in item 1 of 339, zid: 2061130698, lat: 29.815758, lng: -95.52348
# working in item 1 of 339, zid: 2060814941, lat: 29.663954, lng: -95.35872
# working in item 1 of 339, zid: 2067027713, lat: 29.82322, lng: -95.423325
# working in item 1 of 339, zid: 2061359345, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2063073365, lat: 29.566023, lng: -95.25335
# working in item 1 of 339, zid: 2060296469, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2060944887, lat: 29.602442, lng: -95.44372
# working in item 1 of 339, zid: 2062115178, lat: 29.831038, lng: -95.47438
# working in item 1 of 339, zid: 2061130084, lat: 29.815758, lng: -95.52348
# working in item 1 of 339, zid: 2066875899, lat: 29.838493, lng: -95.41691
# working in item 1 of 339, zid: 2066875924, lat: 29.838493, lng: -95.41691
# working in item 1 of 339, zid: 2066875951, lat: 29.838493, lng: -95.41691
# working in item 1 of 339, zid: 2062374086, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2060801214, lat: 29.621563, lng: -95.32965
# working in item 1 of 339, zid: 2060296445, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2060801127, lat: 29.621563, lng: -95.32965
# working in item 1 of 339, zid: 2062780588, lat: 29.86124, lng: -95.42281
# working in item 1 of 339, zid: 2061235289, lat: 29.608494, lng: -95.38633
# working in item 1 of 339, zid: 2061725572, lat: 29.834188, lng: -95.372154
# working in item 1 of 339, zid: 2066875972, lat: 29.838493, lng: -95.41691
# working in item 1 of 339, zid: 2066876124, lat: 29.837975, lng: -95.416374
# working in item 1 of 339, zid: 2066876338, lat: 29.838085, lng: -95.416374
# working in item 1 of 339, zid: 2066876363, lat: 29.838495, lng: -95.41663
# working in item 1 of 339, zid: 2062460444, lat: 29.859009, lng: -95.192314
# working in item 1 of 339, zid: 2063177628, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2060905926, lat: 29.836245, lng: -95.41629
# working in item 1 of 339, zid: 2060905940, lat: 29.836222, lng: -95.41629
# working in item 1 of 339, zid: 2060905980, lat: 29.836199, lng: -95.41629
# working in item 1 of 339, zid: 2060906062, lat: 29.836176, lng: -95.41629
# working in item 1 of 339, zid: 2060906199, lat: 29.836155, lng: -95.41629
# working in item 1 of 339, zid: 2060906243, lat: 29.83613, lng: -95.41629
# working in item 1 of 339, zid: 2060906370, lat: 29.83611, lng: -95.41629
# working in item 1 of 339, zid: 2060906522, lat: 29.836086, lng: -95.41629
# working in item 1 of 339, zid: 2060906886, lat: 29.836063, lng: -95.41629
# working in item 1 of 339, zid: 2061010496, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2066462529, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2062005167, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2073929247, lat: 29.85146, lng: -95.433914
# working in item 1 of 339, zid: 2061717810, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2060375532, lat: 29.73581, lng: -95.52097
# working in item 1 of 339, zid: 2060949317, lat: 29.608494, lng: -95.38633
# working in item 1 of 339, zid: 2061255748, lat: 29.85902, lng: -95.272064
# working in item 1 of 339, zid: 2060490130, lat: 29.588713, lng: -95.22669
# working in item 1 of 339, zid: 2066875807, lat: 29.838493, lng: -95.41691
# working in item 1 of 339, zid: 2071343412, lat: 29.825167, lng: -95.277336
# working in item 1 of 339, zid: 2064076690, lat: 29.898052, lng: -95.179955
# working in item 1 of 339, zid: 2063420127, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2061466855, lat: 29.811197, lng: -95.35167
# working in item 1 of 339, zid: 2062182303, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062182305, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062182306, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062183225, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062183226, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062183227, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062183234, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2064210808, lat: 29.797062, lng: -95.48026
# working in item 1 of 339, zid: 2060303269, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2061909335, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2065573483, lat: 30.008938, lng: -95.443504
# working in item 1 of 339, zid: 2060636184, lat: 29.83455, lng: -95.372574
# working in item 1 of 339, zid: 2062669626, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2062182236, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062182237, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062182238, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062182304, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062182322, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062183235, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062183239, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062183240, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062185703, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2063203725, lat: 29.674067, lng: -95.37452
# working in item 1 of 339, zid: 2062240847, lat: 29.834496, lng: -95.14872
# working in item 1 of 339, zid: 2061114111, lat: 29.815758, lng: -95.52348
# working in item 1 of 339, zid: 2060411034, lat: 29.608494, lng: -95.38633
# working in item 1 of 339, zid: 2062648965, lat: 29.816605, lng: -95.38066
# working in item 1 of 339, zid: 2061227177, lat: 29.834496, lng: -95.14872
# working in item 1 of 339, zid: 2061605374, lat: 29.808163, lng: -95.38908
# working in item 1 of 339, zid: 2062288394, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2060301827, lat: 29.770802, lng: -95.51137
# working in item 1 of 339, zid: 2060639112, lat: 29.898052, lng: -95.179955
# working in item 1 of 339, zid: 2060687422, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2062670183, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2060999635, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2065712102, lat: 29.831364, lng: -95.40282
# working in item 1 of 339, zid: 2063295301, lat: 29.68858, lng: -95.36976
# working in item 1 of 339, zid: 2061290438, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2062760037, lat: 29.796476, lng: -95.4084
# working in item 1 of 339, zid: 2060430526, lat: 30.094297, lng: -95.18492
# working in item 1 of 339, zid: 2062413491, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2062413620, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2064128723, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2061189825, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2061195137, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2061306455, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2061307132, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2065822673, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2060310806, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2061226941, lat: 29.834496, lng: -95.14872
# working in item 1 of 339, zid: 2061111290, lat: 29.815758, lng: -95.52348
# working in item 1 of 339, zid: 2061934886, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2060898942, lat: 29.741009, lng: -95.368546
# working in item 1 of 339, zid: 2067724787, lat: 29.81097, lng: -95.40677
# working in item 1 of 339, zid: 2067749952, lat: 29.81097, lng: -95.40672
# working in item 1 of 339, zid: 2066637737, lat: 29.721933, lng: -95.38175
# working in item 1 of 339, zid: 2062262207, lat: 29.860231, lng: -95.19235
# working in item 1 of 339, zid: 2062368414, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2062412999, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2062413013, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2067396774, lat: 29.809881, lng: -95.321754
# working in item 1 of 339, zid: 2062547774, lat: 29.957811, lng: -95.50152
# working in item 1 of 339, zid: 2062087498, lat: 29.851423, lng: -95.41866
# working in item 1 of 339, zid: 2062182239, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062182321, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062183061, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062183237, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062183238, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062185916, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2065712083, lat: 29.831364, lng: -95.40282
# working in item 1 of 339, zid: 2060302978, lat: 29.825459, lng: -95.65064
# working in item 1 of 339, zid: 2061583774, lat: 29.898052, lng: -95.179955
# working in item 1 of 339, zid: 2060532787, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2066799252, lat: 29.734236, lng: -95.37488
# working in item 1 of 339, zid: 2066461920, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2062368089, lat: 30.091225, lng: -95.18045
# working in item 1 of 339, zid: 2064112330, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2065776905, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2060310701, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2064415881, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2062773051, lat: 29.834496, lng: -95.14872
# working in item 1 of 339, zid: 2069349627, lat: 29.79, lng: -95.664
# working in item 1 of 339, zid: 2061112580, lat: 29.815758, lng: -95.52348
# working in item 1 of 339, zid: 2063492821, lat: 29.848305, lng: -95.42911
# working in item 1 of 339, zid: 2064207656, lat: 29.791502, lng: -95.35387
# working in item 1 of 339, zid: 2065712146, lat: 29.831608, lng: -95.40235
# working in item 1 of 339, zid: 2065712150, lat: 29.831608, lng: -95.40235
# working in item 1 of 339, zid: 2065712163, lat: 29.831411, lng: -95.40238
# working in item 1 of 339, zid: 2066843807, lat: 29.799984, lng: -95.35389
# working in item 1 of 339, zid: 2071503581, lat: 29.725012, lng: -95.590866
# working in item 1 of 339, zid: 2060330265, lat: 29.819944, lng: -95.420425
# working in item 1 of 339, zid: 2062590049, lat: 29.740465, lng: -95.32527
# working in item 1 of 339, zid: 2060295659, lat: 30.093866, lng: -95.186134
# working in item 1 of 339, zid: 2061226902, lat: 29.834496, lng: -95.14872
# working in item 1 of 339, zid: 2063453706, lat: 29.859318, lng: -95.382195
# working in item 1 of 339, zid: 2061235413, lat: 29.834938, lng: -95.41534
# working in item 1 of 339, zid: 2062964400, lat: 29.768827, lng: -95.32409
# working in item 1 of 339, zid: 2067362272, lat: 29.815758, lng: -95.52348
# working in item 1 of 339, zid: 2067772628, lat: 29.808294, lng: -95.521935
# working in item 1 of 339, zid: 2069110269, lat: 29.808277, lng: -95.52255
# working in item 1 of 339, zid: 2069124860, lat: 29.807892, lng: -95.521835
# working in item 1 of 339, zid: 2070235772, lat: 29.807884, lng: -95.52262
# working in item 1 of 339, zid: 2060320256, lat: 29.85947, lng: -95.1925
# working in item 1 of 339, zid: 2061195015, lat: 30.065784, lng: -95.10133
# working in item 1 of 339, zid: 2060310623, lat: 29.85329, lng: -95.4391
# working in item 1 of 339, zid: 2062921103, lat: 29.768936, lng: -95.3241
# working in item 1 of 339, zid: 2060945809, lat: 29.87307, lng: -95.44038
# working in item 1 of 339, zid: 2062796964, lat: 29.76892, lng: -95.32409
# working in item 1 of 339, zid: 2061711108, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061782100, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061782343, lat: 29.82681, lng: -95.42553
# working in item 1 of 339, zid: 2061782434, lat: 29.82681, lng: -95.42553

# %% [markdown]
# #### Output the Coordinates DF

# %%
# Output file name
name = latest_file.split("data")[2]
out_name = 'missing_coordinates_data'+ name

# Create output directory if it does not exist
os.makedirs('./data/', exist_ok=True)

# Save the merged DF to a csv file
df_coord.to_csv(f'./data/{out_name}', index=False)

# %% [markdown]
# ## I manually filled the missing coordinates cells
# ### Now the table need to be re-loaded

# %%
# Load the input data (only the most recent file)
data_path = "data/*.csv"
listing = glob.glob(data_path)
latest_file = max(listing, key=os.path.getctime)
print(f'The file selected is: {latest_file}')
# Out:
# The file selected is: data\manual_edit_fix_cleaned_data_Houston_TX_Houses_merged_2023_1_1_12_5.csv

# %%
# Create the input DF
df_raw = pd.read_csv(latest_file)

# %%
df_raw.head(3)
# Out:
#         zid        Lat        Lng   Price  Bedrooms  Bathrooms  \
# 0  27541924  29.603600 -95.485405  276000       3.0          2
# 1  27542111  29.600388 -95.488210  220000       3.0          2
# 2  27542455  29.595436 -95.485880  230000       4.0          2
#
#    constructedArea  zipCode  hasGarage  hasPool  hasCooling  hasView  \
# 0           3612.0    77489          1        0           1        0
# 1           1270.0    77489          1        0           1        0
# 2           1765.0    77489          1        0           1        0
#
#    yearBuilt  stories  parkingSpaces  annualHOI  schoolElemRating  \
# 0     1971.0      2.0              2       1159               6.0
# 1     1972.0      1.0              1        924               6.0
# 2     1974.0      1.0              2        966               6.0
#
#    schoolElemDist  schoolMidRating  schoolMidDist  schoolHighRating  \
# 0             0.5                3            1.3                 2
# 1             0.3                3            1.3                 2
# 2             0.3                3            1.0                 2
#
#    schoolHighDist  priceIncreased  priceDiff  days  lotAreaSQFT  \
# 0             1.1               1      31000  1213     8764.272
# 1             1.0               1      65100   503     7884.360
# 2             0.6               1     115275  5140     7148.196
#
#                                         Address   lotArea  \
# 0  6602 Indian Lake Dr, Missouri City, TX 77489  8764.272
# 1   6727 Castleview Ln, Missouri City, TX 77489  7884.360
# 2   15902 Ridgerock Rd, Missouri City, TX 77489  7148.196
#
#                                                Image  CountyId  taxRate  \
# 0  https://photos.zillowstatic.com/fp/bc5a7196226...      2698     2.41
# 1  https://photos.zillowstatic.com/fp/1336380a837...      2698     2.41
# 2  https://photos.zillowstatic.com/fp/5603ce32232...      2698     2.41
#
#        annualHOA
# 0  $400 annually
# 1  $144 annually
# 2  $250 annually

# %% [markdown]
# #### Do some more conditioning

# %%
df_copy = df_raw.copy()

df = df_copy.drop(['Address', 'lotArea', 'Image', 'CountyId', 'taxRate', 'annualHOA'], axis=1)
df.head(3)
# Out:
#         zid        Lat        Lng   Price  Bedrooms  Bathrooms  \
# 0  27541924  29.603600 -95.485405  276000       3.0          2
# 1  27542111  29.600388 -95.488210  220000       3.0          2
# 2  27542455  29.595436 -95.485880  230000       4.0          2
#
#    constructedArea  zipCode  hasGarage  hasPool  hasCooling  hasView  \
# 0           3612.0    77489          1        0           1        0
# 1           1270.0    77489          1        0           1        0
# 2           1765.0    77489          1        0           1        0
#
#    yearBuilt  stories  parkingSpaces  annualHOI  schoolElemRating  \
# 0     1971.0      2.0              2       1159               6.0
# 1     1972.0      1.0              1        924               6.0
# 2     1974.0      1.0              2        966               6.0
#
#    schoolElemDist  schoolMidRating  schoolMidDist  schoolHighRating  \
# 0             0.5                3            1.3                 2
# 1             0.3                3            1.3                 2
# 2             0.3                3            1.0                 2
#
#    schoolHighDist  priceIncreased  priceDiff  days  lotAreaSQFT
# 0             1.1               1      31000  1213     8764.272
# 1             1.0               1      65100   503     7884.360
# 2             0.6               1     115275  5140     7148.196

# %% [markdown]
# #### Save the table

# %%
# Output file name
name = latest_file.split("data")[2]
out_name = 'Pre_ML_data'+ name

# Save the merged DF to a csv file
df.to_csv(f'./data/{out_name}', index=False)

# %% [markdown]
# #### QC a specific zid

# %%
host = "zillow-com1.p.rapidapi.com"
url = "https://" + host + "/property" # Query of single property details

# API specific (do not modify)
querystring = {"zpid": '2080317452'}

headers = {
    "X-RapidAPI-Key": key,
    "X-RapidAPI-Host": host
}

response = requests.request("GET", url, headers=headers, params=querystring)
json_response = response.json()

json_response
# Out:
# {'listingProvider': None,
#  'buildingPermits': None,
#  'propertyTaxRate': 2.29,
#  'contact_recipients': [{'agent_reason': 1,
#    'zpro': None,
#    'recent_sales': 0,
#    'review_count': 5,
#    'display_name': 'Marianne Cowan',
#    'zuid': 'X1-ZUwvno69ocbabt_8s1xy',
#    'rating_average': 5,
#    'badge_type': 'Premier Agent',
#    'phone': {'prefix': '626', 'areacode': '281', 'number': '5640'},
#    'image_url': 'https://photos.zillowstatic.com/h_n/ISi7defpty2atb0000000000.jpg'}],
#  'solarPotential': None,
#  'longitude': -95.17974,
#  'zpid': 2080317452,
#  'address': {'city': 'Porter',
#   'neighborhood': None,
#   'state': 'TX',
#   'streetAddress': '0 Hueni Rd',
#   'zipcode': '77365'},
#  'cityId': 39051,
#  'timeOnZillow': '215 days',
#  'url': '/homedetails/0-Hueni-Rd-Porter-TX-77365/2080317452_zpid/',
#  'zestimate': None,
#  'imgSrc': 'https://photos.zillowstatic.com/fp/db183e1ca44ab7626ce8db6903f48fa6-p_d.jpg',
#  'zipcode': '77365',
#  'zestimateLowPercent': None,
#  'livingAreaValue': 0,
#  'dateSold': '',
#  'livingArea': 0,
#  'isListedByOwner': False,
#  'taxHistory': {},
#  'streetAddress': '0 Hueni Rd',
#  'county': None,
#  'stateId': 54,
#  'rentZestimate': 1302,
#  'countyId': 1090,
#  'timeZone': 'America/Chicago',
#  'homeType': 'SINGLE_FAMILY',
#  'livingAreaUnits': 'sqft',
#  'comingSoonOnMarketDate': None,
#  'resoFacts': {'hasAttachedProperty': False,
#   'frontageType': None,
#   'poolFeatures': None,
#   'flooring': None,
#   'foundationDetails': {},
#   'accessibilityFeatures': None,
#   'hasGarage': False,
#   'hasPetsAllowed': None,
#   'bodyType': None,
#   'topography': None,
#   'landLeaseExpirationDate': None,
#   'hasAdditionalParcels': False,
#   'waterViewYN': None,
#   'atAGlanceFacts': [{'factLabel': 'Type',
#     'factValue': 'Single Family Residence'},
#    {'factLabel': 'Year Built', 'factValue': None},
#    {'factLabel': 'Heating', 'factValue': None},
#    {'factLabel': 'Cooling', 'factValue': None},
#    {'factLabel': 'Parking', 'factValue': '0 spaces'},
#    {'factLabel': 'Lot', 'factValue': '22.26 Acres'},
#    {'factLabel': 'Days on Zillow', 'factValue': '215 Days'},
#    {'factLabel': 'Buyers Agency Fee', 'factValue': '3'},
#    {'factLabel': 'Offer Review Date', 'factValue': None}],
#   'offerReviewDate': None,
#   'aboveGradeFinishedArea': None,
#   'view': {},
#   'buyerAgencyCompensationType': '%',
#   'rooms': {},
#   'carportSpaces': None,
#   'cityRegion': 'Porter',
#   'mainLevelBathrooms': None,
#   'hasPrivatePool': None,
#   'associationFeeIncludes': None,
#   'waterSource': None,
#   'exteriorFeatures': {},
#   'coveredSpaces': 0,
#   'inclusions': None,
#   'hasFireplace': None,
#   'zoningDescription': None,
#   'garageSpaces': 0,
#   'sewer': None,
#   'elevationUnits': None,
#   'exclusions': None,
#   'mainLevelBedrooms': None,
#   'numberOfUnitsVacant': None,
#   'hasWaterfrontView': None,
#   'listAOR': None,
#   'lotSize': '22.26 Acres',
#   'entryLevel': None,
#   'irrigationWaterRightsAcres': None,
#   'greenWaterConservation': None,
#   'stories': None,
#   'livingArea': None,
#   'numberOfUnitsInCommunity': None,
#   'listingTerms': None,
#   'otherStructures': None,
#   'associationFee': None,
#   'marketingType': None,
#   'greenIndoorAirQuality': None,
#   'greenSustainability': None,
#   'hasHomeWarranty': False,
#   'associationPhone': None,
#   'greenBuildingVerificationType': None,
#   'elementarySchool': 'Shadow Forest Elementary School',
#   'bedrooms': 0,
#   'architecturalStyle': None,
#   'listingId': None,
#   'structureType': None,
#   'interiorFeatures': None,
#   'horseAmenities': None,
#   'electric': None,
#   'developmentStatus': None,
#   'lotFeatures': ['20 Up to 50 Acres'],
#   'roofType': None,
#   'waterSources': None,
#   'constructionMaterials': {},
#   'fireplaceFeatures': None,
#   'doorFeatures': None,
#   'appliances': None,
#   'daysOnZillow': 215,
#   'bathroomsPartial': None,
#   'bathroomsHalf': None,
#   'depositsAndFees': None,
#   'canRaiseHorses': False,
#   'buildingName': None,
#   'hasAssociation': None,
#   'petsMaxWeight': None,
#   'commonWalls': None,
#   'totalActualRent': None,
#   'additionalParcelsDescription': None,
#   'associationName': None,
#   'allowedPets': None,
#   'communityFeatures': None,
#   'tenantPays': None,
#   'middleOrJuniorSchool': 'Riverwood Middle School',
#   'lotSizeDimensions': None,
#   'roadSurfaceType': ['Concrete'],
#   'hasOpenParking': None,
#   'yearBuilt': None,
#   'livingAreaRangeUnits': None,
#   'irrigationWaterRightsYN': None,
#   'bathroomsFull': 0,
#   'horseYN': None,
#   'incomeIncludes': None,
#   'highSchool': 'Kingwood High School',
#   'leaseTerm': None,
#   'elevation': None,
#   'cropsIncludedYN': None,
#   'attic': None,
#   'subdivisionName': 'Mcclain',
#   'windowFeatures': None,
#   'ownership': None,
#   'woodedArea': None,
#   'middleOrJuniorSchoolDistrict': '29 - Humble',
#   'associationPhone2': None,
#   'buyerAgencyCompensation': '3',
#   'heating': None,
#   'frontageLength': None,
#   'virtualTourURLUnbranded': None,
#   'associationAmenities': None,
#   'propertySubType': ['Single Family Residence'],
#   'hasCooling': None,
#   'belowGradeFinishedArea': None,
#   'hasElectricOnProperty': None,
#   'foundationArea': None,
#   'zoning': None,
#   'hoaFee': None,
#   'livingAreaRange': None,
#   'basementYN': False,
#   'availabilityDate': None,
#   'waterBodyName': None,
#   'waterfrontFeatures': None,
#   'specialListingConditions': None,
#   'buildingAreaSource': None,
#   'taxAnnualAmount': 3571,
#   'parking': 0,
#   'hasView': False,
#   'virtualTour': None,
#   'securityFeatures': None,
#   'cooling': None,
#   'entryLocation': None,
#   'otherFacts': {},
#   'levels': None,
#   'ownershipType': None,
#   'basement': None,
#   'onMarketDate': 1654016584000,
#   'waterView': None,
#   'laundryFeatures': None,
#   'hasAttachedGarage': None,
#   'fencing': None,
#   'spaFeatures': None,
#   'bathrooms': 0,
#   'homeType': 'SingleFamily',
#   'isSeniorCommunity': None,
#   'municipality': None,
#   'bathroomsThreeQuarter': None,
#   'hasSpa': False,
#   'otherParking': None,
#   'associationFee2': None,
#   'parcelNumber': '0431950006507',
#   'hasHeating': None,
#   'associationName2': None,
#   'hasRentControl': None,
#   'elementarySchoolDistrict': '29 - Humble',
#   'otherEquipment': None,
#   'parkingFeatures': {},
#   'buildingArea': '0',
#   'furnished': False,
#   'vegetation': None,
#   'patioAndPorchFeatures': None,
#   'buildingFeatures': None,
#   'builderName': None,
#   'highSchoolDistrict': '29 - Humble',
#   'propertyCondition': None,
#   'storiesTotal': None,
#   'yearBuiltEffective': None,
#   'fireplaces': None,
#   'bathroomsOneQuarter': None,
#   'builderModel': None,
#   'gas': None,
#   'utilities': ['Sewer Not Available', 'Water Not Available'],
#   'greenEnergyEfficient': None,
#   'landLeaseAmount': None,
#   'isNewConstruction': False,
#   'hasLandLease': False,
#   'pricePerSquareFoot': None,
#   'hasCarport': False,
#   'openParkingSpaces': None},
#  'bathrooms': 0,
#  'annualHomeownersInsurance': 2495,
#  'state': 'TX',
#  'description': 'LOOKING for a PIECE OF UNRESTRICTED PROPERTY?  A once in a lifetime opportunity to own unrestricted acreage in Kingwood. 22.25 ACRES TO DO AS YOU PLEASE. Located between Porter and back of Kingwood on Hueni Rd off of Mills Branch Dr. PROPERTY IS LOCATED IN THE 100 YEAR FLOOD PLAIN. Zoned to Kingwood Schools.',
#  'building': None,
#  'propertyTypeDimension': 'Single Family',
#  'yearBuilt': None,
#  'brokerageName': 'RE/MAX Associates Northeast',
#  'price': 594000,
#  'pageViewCount': 105,
#  'monthlyHoaFee': None,
#  'attributionInfo': {'lastUpdated': '2022-12-20 03:52:17',
#   'mlsName': 'HAR',
#   'listingAgreement': 'Exclusive Right to Sell/Lease',
#   'infoString1': '72949792',
#   'infoString20': None,
#   'infoString14': None,
#   'infoString15': None,
#   'infoString11': '2023-01-01 16:32:01',
#   'infoString10': 'Copyright 2023, Houston REALTORS® Information Service, Inc.\nThe information provided is exclusively for consumers’ personal, non-commercial use, and may not be used for any purpose other than to identify prospective properties consumers may be interested in purchasing. \nInformation is deemed reliable but not guaranteed.\n\nThe listing broker’s offer of compensation is made only to participants of the MLS where the listing is filed. ',
#   'coAgentName': None,
#   'coAgentNumber': None,
#   'infoString5': '713-819-9145',
#   'providerLogo': 'https://photos.zillowstatic.com/fp/c762e8317c35d5634ce97b86029da54d-zillow_web_95_35.jpg',
#   'infoString18': None,
#   'mlsDisclaimer': 'Copyright 2023, Houston REALTORS® Information Service, Inc.\nThe information provided is exclusively for consumers’ personal, non-commercial use, and may not be used for any purpose other than to identify prospective properties consumers may be interested in purchasing. \nInformation is deemed reliable but not guaranteed.\n\nThe listing broker’s offer of compensation is made only to participants of the MLS where the listing is filed. ',
#   'brokerPhoneNumber': '281-358-8888',
#   'lastChecked': '2023-01-01 16:32:01',
#   'buyerAgentName': None,
#   'infoString7': '281-358-8888',
#   'infoString6': 'RE/MAX Associates Northeast',
#   'infoString12': '2022-12-20 03:52:17',
#   'coAgentLicenseNumber': None,
#   'infoString13': None,
#   'listingOffices': [{'associatedOfficeType': 'listOffice',
#     'officeName': 'RE/MAX Associates Northeast'}],
#   'buyerAgentMemberStateLicense': None,
#   'brokerName': 'RE/MAX Associates Northeast',
#   'trueStatus': None,
#   'attributionTitle': None,
#   'infoList2': [{'infoField1': 'Thomas Saunders',
#     'infoField2': 'listAgent',
#     'infoField3': 'TREC #0514825'}],
#   'agentName': 'Thomas Saunders',
#   'mlsId': '72949792',
#   'infoList1': [{'infoField1': 'listOffice',
#     'infoField2': 'RE/MAX Associates Northeast'}],
#   'infoString4': 'Thomas Saunders',
#   'agentEmail': 'thomasLsaunders@remax.net',
#   'listingAgents': [{'memberStateLicense': 'TREC #0514825',
#     'memberFullName': 'Thomas Saunders',
#     'associatedAgentType': 'listAgent'}],
#   'agentPhoneNumber': '713-819-9145',
#   'agentLicenseNumber': 'TREC #0514825',
#   'infoString17': 'TREC #0514825',
#   'infoString16': 'thomasLsaunders@remax.net',
#   'buyerBrokerageName': None,
#   'infoString2': 'HAR',
#   'infoString3': 'https://photos.zillowstatic.com/fp/c762e8317c35d5634ce97b86029da54d-zillow_web_95_35.jpg',
#   'infoString19': None},
#  'mortgageRates': {'arm5Rate': 5.488,
#   'fifteenYearFixedRate': 5.389,
#   'thirtyYearFixedRate': 5.968},
#  'homeStatus': 'FOR_SALE',
#  'homeFacts': None,
#  'latitude': 30.093363,
#  'datePosted': '2022-05-31',
#  'bedrooms': 0,
#  'nearbyHomes': [{'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=316x234&zoom=17&center=30.09336280822754,-95.17974090576172&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=BxgDhlt-EWG_QkNhVrn0TUoK_Us='}],
#    'zpid': 161161868,
#    'longitude': -95.17974,
#    'address': {'city': 'Humble',
#     'state': 'TX',
#     'streetAddress': 'Hueni Rd',
#     'zipcode': '77365'},
#    'price': 5000,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.093363},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=316x234&zoom=17&center=30.093475341796875,-95.17964935302734&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=06G-oAbVkAyKqq3wKGZ3r9p7sH4='}],
#    'zpid': 161161869,
#    'longitude': -95.17965,
#    'address': {'city': 'Humble',
#     'state': 'TX',
#     'streetAddress': 'Hueni Rd',
#     'zipcode': '77365'},
#    'price': 375,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.093475},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=316x234&zoom=17&center=30.09358787536621,-95.17955780029297&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=X50R3A37EdYwlXk_sSSChjm0V6U='}],
#    'zpid': 161161870,
#    'longitude': -95.17956,
#    'address': {'city': 'Humble',
#     'state': 'TX',
#     'streetAddress': 'Hueni Rd',
#     'zipcode': '77365'},
#    'price': 250,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.093588},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=316x234&zoom=17&center=30.094654083251953,-95.18033599853516&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=nE9pZLTyLOtYuJIIR8Y88EgUR-8='}],
#    'zpid': 112156159,
#    'longitude': -95.180336,
#    'address': {'city': 'Porter',
#     'state': 'TX',
#     'streetAddress': 'Mills Branch Dr',
#     'zipcode': '77365'},
#    'price': 233957,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.094654},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=6227+Emerald+Bay+Point+Ln%2C+Porter%2C+TX+77365&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=AfwF76bKH4xItH2Iomj_Hkef2cE='}],
#    'zpid': 249895569,
#    'longitude': -95.18104,
#    'address': {'city': 'Porter',
#     'state': 'TX',
#     'streetAddress': '6227 Emerald Bay Point Ln',
#     'zipcode': '77365'},
#    'price': 753900,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.091866},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=316x234&zoom=17&center=30.091629028320312,-95.18083953857422&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=xJ4uzbmNyfGGI_VqEpPeAD1WHWA='}],
#    'zpid': 249895570,
#    'longitude': -95.18084,
#    'address': {'city': 'Porter',
#     'state': 'TX',
#     'streetAddress': 'Emerald Bay Point Ln',
#     'zipcode': '77365'},
#    'price': 53736,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.091629},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=3208+Floral+Garden+Ln%2C+Porter%2C+TX+77365&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=rHhi_YkYUrYWXF4zGCJQkKlzGvA='}],
#    'zpid': 243979901,
#    'longitude': -95.18179,
#    'address': {'city': 'Porter',
#     'state': 'TX',
#     'streetAddress': '3208 Floral Garden Ln',
#     'zipcode': '77365'},
#    'price': 626400,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.09245},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=3212+Floral+Garden+Ln%2C+Porter%2C+TX+77365&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=a_Z7ud1-pzK9RFS3QwKWhatcaFs='}],
#    'zpid': 243979900,
#    'longitude': -95.1819,
#    'address': {'city': 'Porter',
#     'state': 'TX',
#     'streetAddress': '3212 Floral Garden Ln',
#     'zipcode': '77365'},
#    'price': 567700,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 30.092657}],
#  'brokerId': None,
#  'priceHistory': [{'priceChangeRate': 0,
#    'date': '2022-10-14',
#    'source': 'HAR',
#    'postingIsRental': False,
#    'time': 1665705600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'HAR',
#     'infoString3': 'https://photos.zillowstatic.com/fp/c762e8317c35d5634ce97b86029da54d-zillow_web_logo_inf_11.jpg',
#     'infoString1': '72949792'},
#    'pricePerSquareFoot': None,
#    'buyerAgent': None,
#    'event': 'Listed for sale',
#    'price': 594000},
#   {'priceChangeRate': 0,
#    'date': '2022-08-25',
#    'source': 'HAR',
#    'postingIsRental': False,
#    'time': 1661385600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'HAR',
#     'infoString3': 'https://photos.zillowstatic.com/fp/c762e8317c35d5634ce97b86029da54d-zillow_web_logo_inf_11.jpg',
#     'infoString1': '72949792'},
#    'pricePerSquareFoot': None,
#    'buyerAgent': None,
#    'event': 'Pending sale',
#    'price': 594000},
#   {'priceChangeRate': 11.122448979592,
#    'date': '2022-05-31',
#    'source': 'HAR',
#    'postingIsRental': False,
#    'time': 1653955200000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'HAR',
#     'infoString3': 'https://photos.zillowstatic.com/fp/c762e8317c35d5634ce97b86029da54d-zillow_web_logo_inf_11.jpg',
#     'infoString1': '72949792'},
#    'pricePerSquareFoot': None,
#    'buyerAgent': None,
#    'event': 'Listed for sale',
#    'price': 594000},
#   {'priceChangeRate': 0,
#    'date': '2020-08-31',
#    'source': 'Faron Daigle Real Estate',
#    'postingIsRental': False,
#    'time': 1598832000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Faron Daigle Real Estate',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': None,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': 49000},
#   {'priceChangeRate': 0,
#    'date': '2020-04-10',
#    'source': 'Faron Daigle Real Estate',
#    'postingIsRental': False,
#    'time': 1586476800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Faron Daigle Real Estate',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': None,
#    'buyerAgent': None,
#    'event': 'Pending sale',
#    'price': 49000},
#   {'priceChangeRate': 0,
#    'date': '2020-03-27',
#    'source': 'Faron Daigle Real Estate',
#    'postingIsRental': False,
#    'time': 1585267200000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Faron Daigle Real Estate',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': None,
#    'buyerAgent': None,
#    'event': 'Listed for sale',
#    'price': 49000}],
#  'favoriteCount': 4,
#  'schools': [{'link': 'https://www.greatschools.org/school?id=03659&state=TX',
#    'rating': 7,
#    'totalCount': 1,
#    'distance': 1.8,
#    'assigned': None,
#    'name': 'Shadow Forest Elementary School',
#    'studentsPerTeacher': 16,
#    'isAssigned': True,
#    'size': 600,
#    'level': 'Primary',
#    'grades': 'PK-5',
#    'type': 'Public'},
#   {'link': 'https://www.greatschools.org/school?id=03675&state=TX',
#    'rating': 8,
#    'totalCount': 1,
#    'distance': 2.5,
#    'assigned': None,
#    'name': 'Riverwood Middle School',
#    'studentsPerTeacher': 17,
#    'isAssigned': True,
#    'size': 1069,
#    'level': 'Middle',
#    'grades': '6-8',
#    'type': 'Public'},
#   {'link': 'https://www.greatschools.org/school?id=03660&state=TX',
#    'rating': 7,
#    'totalCount': 1,
#    'distance': 3.2,
#    'assigned': None,
#    'name': 'Kingwood High School',
#    'studentsPerTeacher': 17,
#    'isAssigned': True,
#    'size': 2750,
#    'level': 'High',
#    'grades': '9-12',
#    'type': 'Public'}],
#  'zestimateHighPercent': None,
#  'mlsid': '72949792',
#  'countyFIPS': None,
#  'city': 'Porter',
#  'providerListingID': None,
#  'country': 'USA',
#  'currency': 'USD',
#  'listed_by': {'agent_reason': 3,
#   'zpro': False,
#   'recent_sales': 0,
#   'zuid': 'X1-ZUxqv1zuolkt1l_8s1xy',
#   'review_count': 30,
#   'display_name': 'Thomas Saunders',
#   'profile_url': 'https://www.zillow.com/profile/Thomas-L-Saunders/',
#   'business_name': 'RE/MAX Associates Northeast',
#   'rating_average': 5,
#   'phone': None,
#   'badge_type': 'Listing Agent',
#   'image_url': 'https://photos.zillowstatic.com/h_n/ISletqeuue7f0l0000000000.jpg'},
#  'contingentListingType': None}

# %% [markdown]
# ## I conducted some more manual edit to get the table ready for ML
# ### Now the table need to be re-loaded

# %%
data_path = "data/*.csv"
listing = glob.glob(data_path)
latest_file = max(listing, key=os.path.getctime)
print(f'The file selected is: {latest_file}')
# Out:
# The file selected is: data\Edited_Pre_ML_data_Houston_TX_Houses_merged_2023_1_1_12_5.csv

# %%
# Create the input DF
df_ml = pd.read_csv(latest_file)
df_ml = df_ml.drop(['zid'], axis=1)

# %%
df_ml.head(3)
# Out:
#          Lat        Lng   Price  Bedrooms  Bathrooms  constructedArea  \
# 0  29.603600 -95.485405  276000         3          2             3612
# 1  29.600388 -95.488210  220000         3          2             1270
# 2  29.595436 -95.485880  230000         4          2             1765
#
#    zipCode  hasGarage  hasPool  hasCooling  hasView  yearBuilt  stories  \
# 0    77489          1        0           1        0       1971        2
# 1    77489          1        0           1        0       1972        1
# 2    77489          1        0           1        0       1974        1
#
#    parkingSpaces  annualHOI  schoolElemRating  schoolElemDist  \
# 0              2       1159                 6             0.5
# 1              1        924                 6             0.3
# 2              2        966                 6             0.3
#
#    schoolMidRating  schoolMidDist  schoolHighRating  schoolHighDist  \
# 0                3            1.3                 2             1.1
# 1                3            1.3                 2             1.0
# 2                3            1.0                 2             0.6
#
#    priceIncreased  priceDiff  days  lotAreaSQFT
# 0               1      31000  1213     8764.272
# 1               1      65100   503     7884.360
# 2               1     115275  5140     7148.196

# %% [markdown]
# #### QC the df to be input for the ML model

# %%
df_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4499 entries, 0 to 4498
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Lat               4499 non-null   float64
#  1   Lng               4499 non-null   float64
#  2   Price             4499 non-null   int64
#  3   Bedrooms          4499 non-null   int64
#  4   Bathrooms         4499 non-null   int64
#  5   constructedArea   4499 non-null   int64
#  6   zipCode           4499 non-null   int64
#  7   hasGarage         4499 non-null   int64
#  8   hasPool           4499 non-null   int64
#  9   hasCooling        4499 non-null   int64
#  10  hasView           4499 non-null   int64
#  11  yearBuilt         4499 non-null   int64
#  12  stories           4499 non-null   int64
#  13  parkingSpaces     4499 non-null   int64
#  14  annualHOI         4499 non-null   int64
#  15  schoolElemRating  4499 non-null   int64
#  16  schoolElemDist    4499 non-null   float64
#  17  schoolMidRating   4499 non-null   int64
#  18  schoolMidDist     4499 non-null   float64
#  19  schoolHighRating  4499 non-null   int64
#  20  schoolHighDist    4499 non-null   float64
#  21  priceIncreased    4499 non-null   int64
#  22  priceDiff         4499 non-null   int64
#  23  days              4499 non-null   int64
#  24  lotAreaSQFT       4499 non-null   float64
# dtypes: float64(6), int64(19)
# memory usage: 878.8 KB

# %%
# Output file name
name = latest_file.split("data")[2]
out_name = 'ML_data'+ name

# Save the merged DF to a csv file
df_ml.to_csv(f'./data/{out_name}', index=False)
